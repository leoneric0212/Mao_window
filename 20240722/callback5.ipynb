# %%
import data
import pandas as pd


content=data.get_snaOfArea(area='大安區')
df=pd.DataFrame(content)
df.columns=['站點名稱','總數','可借','可還','資料時間']
df.to_dict('records')
# Out:
# [{'站點名稱': '捷運科技大樓站',
#   '總數': 28,
#   '可借': 5,
#   '可還': 23,
#   '資料時間': Timestamp('2024-07-09 09:35:21')},
#  {'站點名稱': '復興南路二段273號前',
#   '總數': 21,
#   '可借': 0,
#   '可還': 21,
#   '資料時間': Timestamp('2024-07-09 09:24:15')},
#  {'站點名稱': '國北教大實小東側門',
#   '總數': 16,
#   '可借': 12,
#   '可還': 4,
#   '資料時間': Timestamp('2024-07-09 09:26:20')},
#  {'站點名稱': '和平公園東側',
#   '總數': 11,
#   '可借': 1,
#   '可還': 10,
#   '資料時間': Timestamp('2024-07-09 09:28:14')},
#  {'站點名稱': '辛亥復興路口西北側',
#   '總數': 16,
#   '可借': 1,
#   '可還': 15,
#   '資料時間': Timestamp('2024-07-09 09:35:21')},
#  {'站點名稱': '復興南路二段280號前',
#   '總數': 11,
#   '可借': 2,
#   '可還': 9,
#   '資料時間': Timestamp('2024-07-09 09:34:19')},
#  {'站點名稱': '復興南路二段340巷口',
#   '總數': 11,
#   '可借': 1,
#   '可還': 10,
#   '資料時間': Timestamp('2024-07-09 09:31:21')},
#  {'站點名稱': '新生南路三段52號前',
#   '總數': 17,
#   '可借': 1,
#   '可還': 15,
#   '資料時間': Timestamp('2024-07-09 09:33:22')},
#  {'站點名稱': '新生南路三段66號前',
#   '總數': 16,
#   '可借': 3,
#   '可還': 13,
# ...
